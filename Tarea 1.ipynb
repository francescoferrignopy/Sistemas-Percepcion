# %% [markdown]
# # Tarea numero 1
# Nombre: Francesco Ferrigno Fecha: 16/09/2026
#
# # Obiectivos:
# 1) aprender a usar notebook
# 2) hacer una tarea que incluye markdown y code
# 3) execute un code simple
#
# # Datos y imagenes
# Imagen local (tras ejecutar la celda de generacion):
# ![Imagen vision](UA2_vision_example.png)

# %%
a = 1
b = 2
c = a+b
print (c)
# Out:
# 3

# %% [markdown]
# 1. Definir el objetivo de la tarea
# 2. Añadir codigo
# 3. Incluir imagenes
#
# - [x] defincion objectivo
# - [ ] Utilizar imagenes
# - [ ] Revisar el notebook

# %% [markdown]
# | Libreria  | Proposito               | Ejemplo             |
# |-----------|-------------------------|---------------------|
# | Pillow    | Cargar/editar imagenes  | `Image.open()`      |
# | Matplotlib| Visualizar y graficar   | `plt.imshow()`      |
# | Pillow    | Visualizar imagen       | `imshow(img_color)` |

# %% [markdown]
# # Formula de respuesta a rampa
# Y(t) = K*τ*($e^-(t/τ)$)-Kτ+Kt
#
# $Y(t) = K \cdot \tau \cdot e^{-t/\tau} - K\tau + Kt$

# %% [markdown]
# ### Relevante
#
# > Nota: revisa todo la parte de la formula.

# %% [markdown]
# ### Mas detalles sobra la tarea
#
# <details>
#   <summary>Haz clic para ver la solucion</summary>
#
#   Para poter aprender bien es necesario pro lo menos completar un tutorial sobre el notebook y en particular la parte de markdown.
# </details>

# %% [markdown]
# #Conclusiones
# 1. la realizacion de la tarea es bastante abordable
# 2. pero para mejor el resultado y utilizar en los proximos temas
